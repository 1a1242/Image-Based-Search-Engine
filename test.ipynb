# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
api_key = '6d207e02198a847aa98d0a2a901485a5'
driver_path = "chromedriver.exe"
# brave_path = "C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe"
option = webdriver.ChromeOptions()
# option.binary_location = brave_path
# option.add_argument("--headless") 
driver = webdriver.Chrome(executable_path=driver_path, chrome_options=option)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15812\1514109558.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=option)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15812\1514109558.py:9: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=option)

# %%
driver.get('https://www.google.com/imghp?hl=EN')
driver.maximize_window()

# %%
path = 'div.dRYYxd > div.nDcEnd > svg'
driver.find_element(By.CSS_SELECTOR, path).click()

# %%
path = 'div.PXT6cd > input'
driver.find_element(By.CSS_SELECTOR, path).send_keys('https://iili.io/HrQBAg9.jpg')

# %%
path = 'div.PXT6cd > div'
driver.find_element(By.CSS_SELECTOR, path).click()

# %%
path = '#yDmH0d > c-wiz > div > div.a4wa9e > div > c-wiz > div > div.Lyudef > div > div.z3qvzf > div:nth-child(2) > span > div.VfPpkd-dgl2Hf-ppHlrf-sM5MNb > button'
driver.find_element(By.CSS_SELECTOR, path).click()

# %%
path = 'div.g8gdQd > div:nth-child(2) > div > div > div > div:nth-child(1) > div'

links = []
path = '#yDmH0d > c-wiz > div > div.a4wa9e > div > c-wiz > div > div.b57KQc > c-wiz > div > div > div > div.UJ8EBe > div.F0mDWe > div > div > div > ul > div > a'
s = driver.find_elements(By.CSS_SELECTOR, path)
for i in s:
    l = i.get_attribute('href')
    links.append(l)
links
# Out:
# ['https://twitter.com/narendramodi/status/1663389817634455552',
#  'https://www.bqprime.com/nation/modi-set-to-hold-bilateral-talks-with-zelenskyy-in-hiroshima',
#  'https://twitter.com/NaMo4PM',
#  'https://timesofindia.indiatimes.com/world/uk/pm-modi-congratulates-king-charles-iii-and-queen-camilla-on-their-coronation/articleshow/100041526.cms',
#  'https://www.entrepreneur.com/en-in/news-and-trends/startups-should-take-full-advantage-of-growing/438156',
#  'https://newsonair.com/2023/02/01/pm-modi-to-virtually-participate-in-krishnaguru-eknaam-akhanda-kirtan-for-world-peace-in-assam-on-3rd-feb/',
#  'https://newsonair.gov.in/Main-News-Details.aspx?id=449387',
#  'https://newsonair.gov.in/News?title=PM-Modi-to-dedicate-75-Digital-Banking-Units-to-nation-on-October-16&id=449387',
#  'https://m.timesofindia.com/world/uk/pm-modi-congratulates-king-charles-iii-and-queen-camilla-on-their-coronation/articleshow/100041526.cms',
# ...

# %%
path = div.G19kAf ENn9pd
